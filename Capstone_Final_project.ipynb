# %% [markdown]
# 1.	A description of the problem and a discussion of the background. (15 marks)
#
# A group of international investors wants to open up a gym. They decided they want to work with luxury equipment and in order to make profit, they identified the area of Aventura, Florida where the gym is likely to succeed. However, if they open too close to one competitor (or two), they will not be able to make as much money as they want and will in fact lose all their money and reputation.
#
# 2.	A description of the data and how it will be used to solve the problem. (15 marks)
# We have queried all the gyms in Aventura, Florida, extracting the information from Foursquare and filtering out all the unnecessary venues.
# We will now proceed to work and process it in order to display it in a clear manner, for which we will have to map it. Also, after reviewing the data, we have realized that a lot of buildings have gyms as well, which will be an issue for our investors since they will need to convince people to pay for their gym instead of using their own. It is very important that we analyze the data correctly so that they do not lose any money by chosing the wrong location.

# %%
#The data will be queried from Forsquare
CLIENT_ID = '2GYJBS0UGDAO1BESAT1GH11BUDEO3AQUQL45EYXCZKLKXHFS' #  Foursquare ID
CLIENT_SECRET = 'HVUHJ4SHDJ1MR4ZCTEWZ5B13JZ3AGIR0DRUPUJJVF5UHZ2G5' #  Foursquare Secret
VERSION = '20200524'
radius = 5000 # define radius
LIMIT=50
LATITUDE = 25.975016
LONGITUDE = -80.123307
#added at the end of url the 'gym' category to filter "non-gym" places
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId=4bf58dd8d48988d175941735'.format(
     CLIENT_ID, 
     CLIENT_SECRET, 
     VERSION, 
     LATITUDE,
     LONGITUDE,  
     radius, 
     LIMIT)

results = requests.get(url).json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0f455cb7df28> in <module>
#      17      LIMIT)
#      18
# ---> 19 results = requests.get(url).json()
#
# NameError: name 'requests' is not defined

# %% [markdown]
# #This code, will yield something like:
# [{"id": "4bc098c574a9a593a33fd0f6", "name": "Spa at the Point", "location": {"lat": 25.972219619450044, "lng": -80.12583851613633, "labeledLatLngs": [{"label": "display", "lat": 25.972219619450044, "lng": -80.12583851613633}], "distance": 401, "cc": "US", "city": "Miami-Dade County", "state": "FL", "country": "United States", "formattedAddress": ["Miami-Dade County, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d1b2941735", "name": "College Gym", "pluralName": "College Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5b16ba6a98fbfc002cac8e7b", "name": "Winners Training Center", "location": {"address": "18260 Collins Ave", "lat": 25.945491, "lng": -80.122108, "labeledLatLngs": [{"label": "display", "lat": 25.945491, "lng": -80.122108}], "distance": 3288, "postalCode": "33160", "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["18260 Collins Ave", "Sunny Isles Beach, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4de12d89d4c040523eb72e62", "name": "Aventura Recreation Center", "location": {"address": "3375 NE 188th St", "lat": 25.950026, "lng": -80.13544399999999, "labeledLatLngs": [{"label": "display", "lat": 25.950026, "lng": -80.13544399999999}], "distance": 3035, "postalCode": "33180", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["3375 NE 188th St", "Aventura, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5a2aa79cfe374044e0e59e09", "name": "Empower Lift", "location": {"address": "15520", "crossStreet": "West Dixie Highway", "lat": 25.91899127632562, "lng": -80.15959095954486, "labeledLatLngs": [{"label": "display", "lat": 25.91899127632562, "lng": -80.15959095954486}], "distance": 7217, "postalCode": "33162", "cc": "US", "city": "North Miami Beach", "state": "FL", "country": "United States", "formattedAddress": ["15520 (West Dixie Highway)", "North Miami Beach, FL 33162", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5844f3ab0393cc195f5c8ac2", "name": "Mystic Pointe Tower 600 GYM", "location": {"address": "3400 NE 192nd St", "lat": 25.952941556154222, "lng": -80.13202444293577, "labeledLatLngs": [{"label": "display", "lat": 25.952941556154222, "lng": -80.13202444293577}], "distance": 2607, "postalCode": "33180", "cc": "US", "city": "Miami", "state": "FL", "country": "United States", "formattedAddress": ["3400 NE 192nd St", "Miami, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5cab7a916fd626002b2b1c91", "name": "Orangetheory Fitness", "location": {"address": "419 N Federal Hwy", "crossStreet": "#107", "lat": 25.990316, "lng": -80.14276, "labeledLatLngs": [{"label": "display", "lat": 25.990316, "lng": -80.14276}], "distance": 2586, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["419 N Federal Hwy (#107)", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "53c59427498e7f72edd6c34a", "name": "Acqualina Gym", "location": {"lat": 25.940874, "lng": -80.120329, "labeledLatLngs": [{"label": "display", "lat": 25.940874, "lng": -80.120329}], "distance": 3812, "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["Sunny Isles Beach, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5e492f71668011000703c008", "name": "Fitness Center At Hyde Resort & Residences", "location": {"address": "4111 S Ocean Dr", "lat": 25.98659, "lng": -80.118515, "labeledLatLngs": [{"label": "display", "lat": 25.98659, "lng": -80.118515}, {"label": "entrance", "lat": 25.987336, "lng": -80.118948}], "distance": 1374, "postalCode": "33019", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["4111 S Ocean Dr", "Hollywood, FL 33019", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4b92b8aef964a520281534e3", "name": "Quadomain", "location": {"address": "2401 S Ocean Dr", "lat": 25.998327655480203, "lng": -80.11761629688293, "labeledLatLngs": [{"label": "display", "lat": 25.998327655480203, "lng": -80.11761629688293}, {"label": "entrance", "lat": 25.998322, "lng": -80.117883}], "distance": 2656, "postalCode": "33019", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["2401 S Ocean Dr", "Hollywood, FL 33019", "United States"]}, "categories": [{"id": "4d954b06a243a5684965b473", "name": "Residential Building (Apartment / Condo)", "pluralName": "Residential Buildings (Apartments / Condos)", "shortName": "Residential", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/apartment_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4c5efb9b6147be9a5a3d9609", "name": "Radius Gym", "location": {"address": "1830 Radius Dr", "lat": 26.01256535010542, "lng": -80.14342497206438, "labeledLatLngs": [{"label": "display", "lat": 26.01256535010542, "lng": -80.14342497206438}], "distance": 4639, "postalCode": "33020", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["1830 Radius Dr", "Hollywood, FL 33020", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5e4439a77f217e0007e93ce1", "name": "Fitnes Center", "location": {"address": "18201 Collins Ave", "crossStreet": "Trump Royale", "lat": 25.944984, "lng": -80.12009, "labeledLatLngs": [{"label": "display", "lat": 25.944984, "lng": -80.12009}], "distance": 3358, "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["18201 Collins Ave (Trump Royale)", "Sunny Isles Beach, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "57eac8a4cd10ad87178568b7", "name": "Oceanview Gym", "location": {"address": "19380 Collins Ave", "lat": 25.954631, "lng": -80.123324, "labeledLatLngs": [{"label": "display", "lat": 25.954631, "lng": -80.123324}], "distance": 2269, "postalCode": "33160", "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["19380 Collins Ave", "Sunny Isles Beach, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4ec8c3e0d3e3e131f3cb5ef9", "name": "The Olympus Private Gym", "location": {"lat": 25.99253389518924, "lng": -80.12571397603317, "labeledLatLngs": [{"label": "display", "lat": 25.99253389518924, "lng": -80.12571397603317}], "distance": 1964, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5bea764ac66666002c0264f9", "name": "Archer Pilates Studio, Inc.", "location": {"address": "2450 Hollywood Blvd #301B", "lat": 26.0108013, "lng": -80.1566826, "labeledLatLngs": [{"label": "display", "lat": 26.0108013, "lng": -80.1566826}], "distance": 5198, "postalCode": "33020", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["2450 Hollywood Blvd #301B", "Hollywood, FL 33020", "United States"]}, "categories": [{"id": "5744ccdfe4b0c0459246b4b2", "name": "Pilates Studio", "pluralName": "Pilates Studios", "shortName": "Pilates Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4d59c22235966dcb05aa5828", "name": "Yogarosa", "location": {"lat": 25.986933068546058, "lng": -80.1420655514431, "labeledLatLngs": [{"label": "display", "lat": 25.986933068546058, "lng": -80.1420655514431}], "distance": 2298, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "venuePage": {"id": "439356111"}, "referralId": "v-1590460302", "hasPerk": false}, {"id": "5db0bd678e3e4e0008656a47", "name": "CFP9", "location": {"lat": 25.986521, "lng": -80.128891, "labeledLatLngs": [{"label": "display", "lat": 25.986521, "lng": -80.128891}], "distance": 1397, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4cae7c35db32f04d3d37b04d", "name": "Gym @ Ocean 3", "location": {"address": "18911 Collins Ave", "lat": 25.94985053305321, "lng": -80.11993389243872, "labeledLatLngs": [{"label": "display", "lat": 25.94985053305321, "lng": -80.11993389243872}], "distance": 2821, "postalCode": "33160", "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["18911 Collins Ave", "Sunny Isles Beach, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5347dbb8498e019ff4f456a5", "name": "Doubletree Gym & Spa", "location": {"address": "Doubletree Hotel", "lat": 25.93694380319683, "lng": -80.12020654663031, "labeledLatLngs": [{"label": "display", "lat": 25.93694380319683, "lng": -80.12020654663031}], "distance": 4249, "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["Doubletree Hotel", "Sunny Isles Beach, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4ad9f99ff964a5209c1c21e3", "name": "Jungle Gym", "location": {"address": "2968 Aventura Blvd", "lat": 25.960065, "lng": -80.141092, "labeledLatLngs": [{"label": "display", "lat": 25.960065, "lng": -80.141092}, {"label": "entrance", "lat": 25.96079, "lng": -80.14093}], "distance": 2436, "postalCode": "33180", "cc": "US", "city": "Miami", "state": "FL", "country": "United States", "formattedAddress": ["2968 Aventura Blvd", "Miami, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4db307bea86e8d270766c66d", "name": "Trump Fitness Center", "location": {"address": "18001 Collins Ave Fl 2", "crossStreet": "Trump International Beach Resort", "lat": 25.944312369417514, "lng": -80.12035923259971, "labeledLatLngs": [{"label": "display", "lat": 25.944312369417514, "lng": -80.12035923259971}], "distance": 3430, "postalCode": "33160", "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["18001 Collins Ave Fl 2 (Trump International Beach Resort)", "Sunny Isles Beach, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4fb5083ae4b06449f9319067", "name": "Diplomat Health Club", "location": {"address": "3555 S Ocean Dr", "lat": 25.99112185847049, "lng": -80.11818117534823, "labeledLatLngs": [{"label": "display", "lat": 25.99112185847049, "lng": -80.11818117534823}], "distance": 1864, "postalCode": "33019", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["3555 S Ocean Dr", "Hollywood, FL 33019", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4d895ea27139b1f73fc5b4d4", "name": "Beach Place Gym", "location": {"lat": 25.933596229745092, "lng": -80.1252941151362, "labeledLatLngs": [{"label": "display", "lat": 25.933596229745092, "lng": -80.1252941151362}], "distance": 4615, "cc": "US", "state": "Florida", "country": "United States", "formattedAddress": ["Florida", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4e31fe471495a9fd30d51d6b", "name": "Man Of Steel Hands Clark Kent Kind Knead", "location": {"lat": 25.983023, "lng": -80.120065, "labeledLatLngs": [{"label": "display", "lat": 25.983023, "lng": -80.120065}], "distance": 948, "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["Hallandale, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "528a4c47498e0e70ce06a206", "name": "Renee Ricca's Pilates Center", "location": {"address": "18131 Biscayne Blvd", "lat": 25.943064, "lng": -80.147091, "labeledLatLngs": [{"label": "display", "lat": 25.943064, "lng": -80.147091}], "distance": 4279, "postalCode": "33160", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["18131 Biscayne Blvd", "Aventura, FL 33160", "United States"]}, "categories": [{"id": "5744ccdfe4b0c0459246b4b2", "name": "Pilates Studio", "pluralName": "Pilates Studios", "shortName": "Pilates Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4ca8ee53b7106dcbf5b277a5", "name": "Intracoastal Yacht Club", "location": {"address": "16925 N Bay Rd.", "lat": 25.931380888018534, "lng": -80.12675955285287, "labeledLatLngs": [{"label": "display", "lat": 25.931380888018534, "lng": -80.12675955285287}], "distance": 4869, "postalCode": "33160", "cc": "US", "city": "Sunny Isles Beach", "state": "FL", "country": "United States", "formattedAddress": ["16925 N Bay Rd.", "Sunny Isles Beach, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d130941735", "name": "Building", "pluralName": "Buildings", "shortName": "Building", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4b2409a8f964a520a35f24e3", "name": "Williams Island Spa", "location": {"address": "6000 Island Blvd", "lat": 25.942695595626947, "lng": -80.13608908399159, "labeledLatLngs": [{"label": "display", "lat": 25.942695595626947, "lng": -80.13608908399159}], "distance": 3818, "postalCode": "33160", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["6000 Island Blvd", "Aventura, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4f8561cee4b062a55652e105", "name": "Orangetheory Fitness", "location": {"address": "18839A Biscayne Blvd", "lat": 25.9502590811057, "lng": -80.14426026299815, "labeledLatLngs": [{"label": "display", "lat": 25.9502590811057, "lng": -80.14426026299815}], "distance": 3463, "postalCode": "33180", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["18839A Biscayne Blvd", "Aventura, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4bc899ff2f94d13a95ef137f", "name": "Olympia Gym", "location": {"address": "20335 Biscayne Blvd # L-201", "lat": 25.9641051, "lng": -80.14399999999999, "labeledLatLngs": [{"label": "display", "lat": 25.9641051, "lng": -80.14399999999999}], "distance": 2400, "postalCode": "33180", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["20335 Biscayne Blvd # L-201", "Aventura, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "venuePage": {"id": "155455808"}, "referralId": "v-1590460302", "hasPerk": false}, {"id": "5c2d8b771cf2e1002c944a75", "name": "LooksGood Salon & Yoga", "location": {"address": "950 S Federal Hwy", "lat": 26.003475, "lng": -80.14311599999999, "labeledLatLngs": [{"label": "display", "lat": 26.003475, "lng": -80.14311599999999}], "distance": 3737, "postalCode": "33020", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["950 S Federal Hwy", "Hollywood, FL 33020", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "51bdddbc498ed389ae279140", "name": "Steel Edge CrossFit", "location": {"address": "20855 NE 16th Ave # C2", "lat": 25.967657771688536, "lng": -80.16983698422857, "labeledLatLngs": [{"label": "display", "lat": 25.967657771688536, "lng": -80.16983698422857}], "distance": 4728, "postalCode": "33179", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["20855 NE 16th Ave # C2", "Aventura, FL 33179", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "venuePage": {"id": "97161652"}, "referralId": "v-1590460302", "hasPerk": false}, {"id": "518ad886498e71e095d5e61e", "name": "Bommarito Performance Systems", "location": {"address": "18900 NE 25th Ave", "lat": 25.94954834486357, "lng": -80.15402530872082, "labeledLatLngs": [{"label": "display", "lat": 25.94954834486357, "lng": -80.15402530872082}], "distance": 4182, "postalCode": "33180", "cc": "US", "city": "Miami", "state": "FL", "country": "United States", "formattedAddress": ["18900 NE 25th Ave", "Miami, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5b90d4141ffe97002cf68ffe", "name": "Primary Care Physicians of Florida - Aventura", "location": {"address": "21000 NE 28th Ave Ste 100", "lat": 25.9694519, "lng": -80.1463042, "labeledLatLngs": [{"label": "display", "lat": 25.9694519, "lng": -80.1463042}, {"label": "entrance", "lat": 25.969467, "lng": -80.146171}], "distance": 2383, "postalCode": "33180", "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["21000 NE 28th Ave Ste 100", "Aventura, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d177941735", "name": "Doctor's Office", "pluralName": "Doctor's Offices", "shortName": "Doctor's Office", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4f7b0e23e4b0b5158663828a", "name": "Coached Fitness", "location": {"address": "730 W Hallandale Beach Blvd #106", "lat": 25.993031136704175, "lng": -80.1280695211831, "labeledLatLngs": [{"label": "display", "lat": 25.993031136704175, "lng": -80.1280695211831}], "distance": 2061, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["730 W Hallandale Beach Blvd #106", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4ed79741b6346530d08b8c66", "name": "My Addiction Cycling & Yoga", "location": {"address": "17055 West Dixie Hwy", "lat": 25.932510011957046, "lng": -80.1530659403941, "labeledLatLngs": [{"label": "display", "lat": 25.932510011957046, "lng": -80.1530659403941}], "distance": 5591, "postalCode": "33160", "cc": "US", "city": "North Miami Beach", "state": "FL", "country": "United States", "formattedAddress": ["17055 West Dixie Hwy", "North Miami Beach, FL 33160", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5210384e498e735d87e3e403", "name": "Courtyard Aventura Gym", "location": {"lat": 25.952964, "lng": -80.14403, "labeledLatLngs": [{"label": "display", "lat": 25.952964, "lng": -80.14403}], "distance": 3213, "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["Aventura, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4ce810bf595cb1f7677fc614", "name": "Exotic Workouts Pole Fitness", "location": {"address": "2010 NE 164th St", "lat": 25.92699483215569, "lng": -80.15948828357018, "labeledLatLngs": [{"label": "display", "lat": 25.92699483215569, "lng": -80.15948828357018}], "distance": 6456, "postalCode": "33162", "cc": "US", "city": "North Miami Beach", "state": "FL", "country": "United States", "formattedAddress": ["2010 NE 164th St", "North Miami Beach, FL 33162", "United States"]}, "categories": [{"id": "4bf58dd8d48988d175941735", "name": "Gym / Fitness Center", "pluralName": "Gyms or Fitness Centers", "shortName": "Gym / Fitness", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4e9c90619a52edbd66296bd9", "name": "Yoga Star Studio", "location": {"address": "8701 Collins Ave", "lat": 26.0231523, "lng": -80.1407923, "labeledLatLngs": [{"label": "display", "lat": 26.0231523, "lng": -80.1407923}], "distance": 5636, "postalCode": "33154", "cc": "US", "city": "Surfside", "state": "FL", "country": "United States", "formattedAddress": ["8701 Collins Ave", "Surfside, FL 33154", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4e556adac65bfef9a55dc7bd", "name": "Hollywood Kung Fu Academy", "location": {"address": "1864 Polk Street", "crossStreet": "US1", "lat": 26.013035902109173, "lng": -80.1442551612854, "labeledLatLngs": [{"label": "display", "lat": 26.013035902109173, "lng": -80.1442551612854}], "distance": 4722, "postalCode": "33021", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["1864 Polk Street (US1)", "Hollywood, FL 33021", "United States"]}, "categories": [{"id": "4bf58dd8d48988d101941735", "name": "Martial Arts Dojo", "pluralName": "Martial Arts Dojos", "shortName": "Martial Arts", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_", "suffix": ".png"}, "primary": true}], "venuePage": {"id": "98461478"}, "referralId": "v-1590460302", "hasPerk": false}, {"id": "500f2242e4b0daa610596561", "name": "zumba fitness", "location": {"lat": 25.985661593549914, "lng": -80.1422395963937, "labeledLatLngs": [{"label": "display", "lat": 25.985661593549914, "lng": -80.1422395963937}], "distance": 2234, "postalCode": "33026", "cc": "US", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["Hollywood, FL 33026", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "52ebb55311d271ba040a7b10", "name": "Promenade GYM", "location": {"lat": 25.956864286387155, "lng": -80.13197892917846, "labeledLatLngs": [{"label": "display", "lat": 25.956864286387155, "lng": -80.13197892917846}], "distance": 2199, "cc": "US", "city": "Aventura", "state": "FL", "country": "United States", "formattedAddress": ["Aventura, FL", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4e772b8dd22d80eb33f29d90", "name": "Leslie Apartments Gym", "location": {"address": "200 Leslie Dr", "lat": 25.988353113853147, "lng": -80.13037047743119, "labeledLatLngs": [{"label": "display", "lat": 25.988353113853147, "lng": -80.13037047743119}], "distance": 1644, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["200 Leslie Dr", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4ffd7fcee4b0308ece40195d", "name": "Oceanview Park Fitness Centre", "location": {"address": "800 Parkview Dr", "lat": 25.995892, "lng": -80.120535, "labeledLatLngs": [{"label": "display", "lat": 25.995892, "lng": -80.120535}], "distance": 2340, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["800 Parkview Dr", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4c606b9c13791b8dab7e4faf", "name": "Yoga One", "location": {"address": "2 Oakwood Boulevard Suite 163", "crossStreet": "Sheridan and Stirling", "lat": 26.0166388969453, "lng": -80.14877495441374, "labeledLatLngs": [{"label": "display", "lat": 26.0166388969453, "lng": -80.14877495441374}], "distance": 5287, "postalCode": "33020", "cc": "US", "neighborhood": "Hollywood, FL", "city": "Hollywood", "state": "FL", "country": "United States", "formattedAddress": ["2 Oakwood Boulevard Suite 163 (Sheridan and Stirling)", "Hollywood, FL 33020", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "venuePage": {"id": "80766192"}, "referralId": "v-1590460302", "hasPerk": false}, {"id": "4c5acb34f346c9286ed24fca", "name": "LA Fitness", "location": {"address": "3455 NE 207th St", "lat": 25.968214462761182, "lng": -80.13212418324336, "labeledLatLngs": [{"label": "display", "lat": 25.968214462761182, "lng": -80.13212418324336}], "distance": 1162, "postalCode": "33180", "cc": "US", "city": "Miami", "state": "FL", "country": "United States", "formattedAddress": ["3455 NE 207th St", "Miami, FL 33180", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "5d5174c352578c000763de8e", "name": "TITLE Boxing Club Hallandale Beach", "location": {"address": "1720 E Hallandale Beach Blvd", "lat": 25.984712, "lng": -80.131179, "labeledLatLngs": [{"label": "display", "lat": 25.984712, "lng": -80.131179}], "distance": 1336, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["1720 E Hallandale Beach Blvd", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "52f2ab2ebcbc57f1066b8b47", "name": "Boxing Gym", "pluralName": "Boxing Gyms", "shortName": "Boxing Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "venuePage": {"id": "554593293"}, "referralId": "v-1590460302", "hasPerk": false}, {"id": "4c8963353dc2a1cda1c2a332", "name": "Premier Wellness Center & Spa", "location": {"address": "1250 E Hallandale Beach Blvd", "lat": 25.985466084901272, "lng": -80.13555201992051, "labeledLatLngs": [{"label": "display", "lat": 25.985466084901272, "lng": -80.13555201992051}], "distance": 1689, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["1250 E Hallandale Beach Blvd", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d176941735", "name": "Gym", "pluralName": "Gyms", "shortName": "Gym", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}, {"id": "4c99f75fbdaf9c74396064ba", "name": "OM'echaye", "location": {"address": "1100 E Hallandale Beach Blvd", "crossStreet": "Between 10th & 12 Ave", "lat": 25.985520207977405, "lng": -80.13689318110877, "labeledLatLngs": [{"label": "display", "lat": 25.985520207977405, "lng": -80.13689318110877}], "distance": 1793, "postalCode": "33009", "cc": "US", "city": "Hallandale", "state": "FL", "country": "United States", "formattedAddress": ["1100 E Hallandale Beach Blvd (Between 10th & 12 Ave)", "Hallandale, FL 33009", "United States"]}, "categories": [{"id": "4bf58dd8d48988d102941735", "name": "Yoga Studio", "pluralName": "Yoga Studios", "shortName": "Yoga Studio", "icon": {"prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_", "suffix": ".png"}, "primary": true}], "referralId": "v-1590460302", "hasPerk": false}]
#
# Which will then be processed to extract relevant information.

# %% [markdown]
# Code used:
# We will first import the required software features, and later will proceed to query Foursqure. Steps will be detailed coming up.

# %%
# !pip install geocoder
# !pip install folium

# !pip install BeautifulSoup4
import numpy as np
import pandas as pd
import requests
import json
import lxml.html as lh
import bs4 as BeautiufulSoup
import urllib.request
import sys
#!conda install -c conda-forge folium=0.5.0 --yes
#!pip install -c conda-forge folium
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from sklearn.cluster import KMeans
import folium 

print("done importing")
# Out:
# ...
#      |████████████████████████████████| 102kB 6.9MB/s ta 0:00:011
# ...
#      |████████████████████████████████| 102kB 8.8MB/s ta 0:00:011
# ...
# done importing

# %% [markdown]
# Now that we have imported everything we need, let's code it up!

# %%
CLIENT_ID = '2GYJBS0UGDAO1BESAT1GH11BUDEO3AQUQL45EYXCZKLKXHFS' # My Foursquare ID
CLIENT_SECRET = 'HVUHJ4SHDJ1MR4ZCTEWZ5B13JZ3AGIR0DRUPUJJVF5UHZ2G5' # My Foursquare Secret
VERSION = '20200524'
radius = 5000 # defined radius of 5km
LIMIT=50
LATITUDE = 25.975016 #manually found for Aventura, FL
LONGITUDE = -80.123307 #same as above
#added at the end of url the 'gym' category to filter "non-gym" places where it says &categoryId=4b....
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId=4bf58dd8d48988d175941735'.format(
     CLIENT_ID, 
     CLIENT_SECRET, 
     VERSION, 
     LATITUDE,
     LONGITUDE,  
     radius, 
     LIMIT)

results = requests.get(url).json()

# %% [markdown]
# Let's see what we have!

# %%
print(results)
# Out:
# {'meta': {'code': 200, 'requestId': '5eccd037216785001b3702e9'}, 'response': {'venues': [{'id': '4bc098c574a9a593a33fd0f6', 'name': 'Spa at the Point', 'location': {'lat': 25.972219619450044, 'lng': -80.12583851613633, 'labeledLatLngs': [{'label': 'display', 'lat': 25.972219619450044, 'lng': -80.12583851613633}], 'distance': 401, 'cc': 'US', 'city': 'Miami-Dade County', 'state': 'FL', 'country': 'United States', 'formattedAddress': ['Miami-Dade County, FL', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d1b2941735', 'name': 'College Gym', 'pluralName': 'College Gyms', 'shortName': 'Gym', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1590480981', 'hasPerk': False}, {'id': '53c59427498e7f72edd6c34a', 'name': 'Acqualina Gym', 'location': {'lat': 25.940874, 'lng': -80.120329, 'labeledLatLngs': [{'label': 'display', 'lat': 25.940874, 'lng': -80.120329}], 'distance': 3812, 'cc': 'US', 'city': 'Sunn
# ...

# %% [markdown]
# Well, that's a lot of information! Let's make it prettier by removing all the unnecessary.

# %%
results_json = json.dumps(results['response']['venues']) #making it a json
df = pd.read_json(results_json) #now it's a dataframe

df['lat'] = df['location'].apply(lambda x: x.get('lat')) #now let's keep what we really want
df['lng'] = df['location'].apply(lambda x: x.get('lng'))
df = df[["name","lat","lng"]] #the only 3 columns we care about

# %% [markdown]
# Let's see what we have now!

# %%
df
# Out:
#                                              name        lat        lng
# 0                                Spa at the Point  25.972220 -80.125839
# 1                                   Acqualina Gym  25.940874 -80.120329
# 2                                    Empower Lift  25.918991 -80.159591
# 3                     Mystic Pointe Tower 600 GYM  25.952942 -80.132024
# 4      Fitness Center At Hyde Resort & Residences  25.986590 -80.118515
# 5                         Winners Training Center  25.945491 -80.122108
# 6                                   Fitnes Center  25.944984 -80.120090
# 7                                      Radius Gym  26.012565 -80.143425
# 8                      Aventura Recreation Center  25.950026 -80.135444
# 9                            Orangetheory Fitness  25.990316 -80.142760
# 10                                  Oceanview Gym  25.954631 -80.123324
# 11                    Archer Pilates Studio, Inc.  26.010801 -80.156683
# ...

# %% [markdown]
# Okay, this is good. Now if only we could see it on a map, right?

# %%
venues_map = folium.Map(location=[LATITUDE, LONGITUDE], zoom_start=14)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Well, this is nice, we like what we see. But seems like we're missing something!
# Oh, right! Let's throw in some gyms.

# %%
nearby_venues = df
for lat, lng in zip(nearby_venues.lat, nearby_venues.lng):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Okay, this is looking good! And we kinda know where we might end up. Except that the wealthier regions are East of US-1. I wonder if we can somehow write it into the code?
# For this, we need to define the range in which we will locate the gym. For that, we can create a geometric shape that will include the coordinates in which a gym location would be acceptable. On a map app, we retrieved the following:
# - left top 25.985574,-80.148031
# - right bottom 25.954767,-80.118334
#
# #- top right 25.985574,-80.118334
# #- left bottom 25.947890, -80.146798
# Let's transform it into dots we can plot.#
#
# These measurements, are telling us that for the coordinates for the gym:
# - Lattitude will be between: 25.947890 and 25.985574
# - Longitude will be between: -80.118334 and -80.148031
#
# Let's draw another map, just for the area we're interested in!

# %%
#Since there are no tariffs, let's import some more stuff
import seaborn as sns
import webbrowser
from folium.plugins import HeatMap #let's turn the heat up

# %%
import folium.plugins as plugins
gymz = df[['lat', 'lng']].as_matrix()

# plot heatmap
venues_map.add_children(plugins.HeatMap(gymz, radius=38))
venues_map
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   from ipykernel import kernelapp as app
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have obtained a heat map, we can properly visualize where there are windows of opportunities, as well as which areas should the investors stay away from.
